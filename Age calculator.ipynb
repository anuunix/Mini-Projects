# %%
age = int(input("Enter your age please:"))
age_type = len(str(age))
cur_y = int(input("Enter current year:"))

if age_type == 2:
         To_100 = 100 - age
         print(f"your age to reach 100 is:{To_100}")
elif age_type == 4:
        To_100 = 100 + age
        print(f"your age to reach 100 is:{To_100}")
else:
    print("Input below age or beyond age")

other = input("Enter y if you search for any particular age")
ran_y = int(input("Enter random year"))
if other == 'y' and age_type==4:
    result =ran_y-cur_y
    print(f"You will reach this year in age: {result}")
else:
    print("Please enter your age in year's format")
